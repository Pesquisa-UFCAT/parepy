# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
path = r'C:\Users\wande\OneDrive\Documentos\Devs\PAREPYDEV-NEW'
sys.path.append(path)
pd.set_option('display.max_columns', None)
from parepy_toolbox import *

# %%
x = crude_sampling_zero_one(10, 10)

# %%
x = lhs_sampling_zero_one(10, 1)

# %%
# Sampling
n = 150
x = uniform_sampling({'a': 10, 'b': 20}, 'mcs', n)
y = uniform_sampling({'a': 10, 'b': 20}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
n = 100
x1 = uniform_sampling({'a': 10, 'b': 20}, 'mcs', n, 24)
x2 = uniform_sampling({'a': 10, 'b': 20}, 'mcs', n)
print(x1, '\n', x2)
# Out:
# [13.302688366693154, 14.051773156391437, 15.74737819327192, 15.063997672701479, 15.642125074302507, 15.69687310508402, 18.74116531240741, 10.86430460990973, 17.424752706865625, 18.203672644347485, 17.121600700271657, 14.099256071864978, 19.429537746552825, 10.309491363041207, 18.029399687936355, 16.0204862526199, 10.411262315969344, 13.323994119712985, 13.782726447389111, 11.760453278088804, 16.426008470130764, 14.392408926642883, 17.158048345819097, 13.714370832039608, 10.541806658692748, 17.156999042268104, 17.330452988013903, 10.82144802372493, 14.654624241876759, 14.55206042098986, 19.148759806208297, 15.977406372616365, 13.074423124793745, 18.806327202543365, 13.236547013215874, 17.26371437871631, 11.886248434213563, 12.151184049536196, 11.457340603322008, 18.208283678333395, 11.91708414055554, 12.64886770329202, 12.02604898122535, 18.028609677665024, 15.019787123332435, 12.083437507524739, 19.056283808049436, 18.152075600764427, 13.10616259816802, 13.32703661472843, 11.023682899236737, 10.960896605708513, 17.182356221049293, 18.27313634512406, 16.874061726910544, 12.513322805201483, 18.49634448793687, 12.43249223566538, 12.559511417722284, 16.620807107354697, 12.463597646967187, 17.89506408251962, 13.250808504862684, 18.500534520019485, 18.53258550065995, 15.90025442796092, 18.764266630869233, 16.43607470936137, 13.425929166311024, 12.825805066159917, 17.80717776575051, 11.41710815684981, 17.30562523245002, 15.47960355677715, 10.365623280308258, 12.12415568913942, 14.969104402064191, 12.313615883489504, 16.851985435925634, 17.34920401925008, 19.723884980119045, 18.939386946020406, 16.22932788702784, 16.633884863469795, 17.098553493316658, 11.135189369315446, 10.840251129026315, 18.874613156361477, 18.310967225303575, 14.471536160666073, 12.260713457902831, 10.893430921953243, 17.640570086729543, 13.117375643553256, 16.136167704106796, 14.025338514521138, 14.396678716343537, 14.28919035102188, 12.948640733959483, 16.145082894174692]
285371, 11.486015432113678, 8.460690827068202, 9.1236944436092, 11.023749095211356, 8.777439597815583, 8.652245131976692, 9.286502012031285, 9.994729117220626, 10.543908730819807, 8.964074567604417, 11.033692336652889, 10.453466455627549, 10.557794222750164, 10.818009140371883, 10.06209391686073, 9.877525432378667, 11.019822501109479, 9.212453332476953, 10.585103356803849, 10.483489234101253, 10.769136293395102, 9.850439252263218, 10.284790630878781, 9.871957639252106, 10.485939424680463, 9.499213943466748, 10.307219435775806, 9.925654559878097, 9.964321554554374]
#  [16.4374642808408, 15.45695380832667, 10.392752059237994, 13.773600569156837, 5.125617566485921, 10.29528297200991, 14.57332550494375, 6.266632452223073, 13.271639550308823, 13.467222224396616, 11.746337060138632, 6.3271213795944306, 11.985774403099498, 13.966285862068279, 12.83516013417741, 8.946752890764541, 12.441631532995068, 6.283776019474822, 8.038298554336386, 13.445309467740538, 7.371705070720173, 9.124737855320687, 10.704797303398623, 7.571985763279186, 10.87178409972727, 9.570749504597927, 11.308567635652308, 6.83637474843068, 6.830417431012996, 12.702945215469803, 13.05190312064438, 11.762054826443128, 10.519734119887525, 8.784762254977096, 7.97713408013346, 12.606987560741764, 10.847333176662836, 8.451224903179876, 8.133076093044984, 9.777122134379702, 12.684131060880306, 12.21150109527703, 12.334723676555125, 9.064923826888554, 9.10383704759887, 10.832208885044851, 11.981919793562671, 12.056199108390835, 7.835108207959726, 9.510513806134812, 12.089607218050993, 10.735417909457704, 10.553435399513475, 11.8644290607078, 7.908081602189895, 11.206743050462334, 12.029675654200924, 8.777318351324864, 10.912819552667202, 8.069965007169602, 11.261300402211075, 10.086083081307528, 8.216847556801394, 10.24844566595203, 11.799143462277014, 9.206347175515592, 8.190172696088394, 9.09410513443584, 11.718829131082426, 9.545424702950655, 8.670162263333403, 11.617622437769592, 8.818373917756844, 8.920637338536382, 8.511379597885512, 11.481815173312306, 9.351266016129859, 10.105957068192902, 8.914308042621284, 8.830064211016724, 9.176269934959523, 10.580148037494716, 9.81429939987081, 8.909366172764422, 9.561918311917818, 11.097586002792358, 9.132486714308394, 8.984152261064857, 9.949748539637737, 10.620170414083447, 9.208364515384801, 10.63444224705107, 10.480309670284738, 10.372340923781975, 9.347056234888615, 9.978592522556161, 9.952245380731782, 9.720467227814385, 9.70033791328764, 9.734270145091852]

# %%
# Sampling
n = 4000
x = normal_sampling({'mean': 10, 'sigma': 2}, 'mcs', n)
y = normal_sampling({'mean': 10, 'sigma': 2}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 400
x = gumbel_max_sampling({'mean': 10, 'sigma': 5}, 'mcs', n)
y = gumbel_max_sampling({'mean': 10, 'sigma': 5}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 400
x = gumbel_min_sampling({'mean': 10, 'sigma': 5}, 'mcs', n)
y = gumbel_min_sampling({'mean': 10, 'sigma': 5}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 400
x = triangular_sampling({'min': 2, 'mode': 6, 'max': 7}, 'mcs', n)
y = triangular_sampling({'min': 2, 'mode': 6, 'max': 7}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 4000
x = lognormal_sampling({'mean': 1, 'sigma': 0.4}, 'mcs', n)
y = lognormal_sampling({'mean': 1, 'sigma': 0.4}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()
