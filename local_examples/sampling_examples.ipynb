# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# path = r'C:\Users\wande\OneDrive\Documentos\GitHub\PAREPY'
path = r'C:\Users\wander\Documents\GitHub\PAREPYDEV_NEW'
path  = r'C:\Users\wande\OneDrive\Documentos\GitHub\PAREPY'
sys.path.append(path)
pd.set_option('display.max_columns', None)
from parepy_toolbox import crude_sampling_zero_one, lhs_sampling_zero_one, sampling

# %%
x = crude_sampling_zero_one(10, 10)
x
# Out:
# [0.9560017096289753,
#  0.20768181007914688,
#  0.8284448852745308,
#  0.14928212308202027,
#  0.5128046164365648,
#  0.13591960402050662,
#  0.6890364797811311,
#  0.841747724312279,
#  0.4255089974049766,
#  0.9569260034533662]

# %%
x = lhs_sampling_zero_one(10, 2, 2)
x
# Out:
# array([[0.07383879, 0.24377343],
#        [0.17015089, 0.08499377],
#        [0.21857743, 0.75673692],
#        [0.39080841, 0.63307027],
#        [0.43998995, 0.95772153],
#        [0.52714395, 0.53668156],
#        [0.68120989, 0.3032564 ],
#        [0.79448534, 0.43169352],
#        [0.87250306, 0.86083752],
#        [0.9342567 , 0.18127474]])

# %%
# Sampling
n = 400
x = uniform_sampling(parameters={'min': 10, 'max': 20}, method='mcs', n_samples=n)
y = uniform_sampling(parameters={'min': 10, 'max': 20}, method='lhs', n_samples=n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Density')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Density')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Sampling
#       2 n = 400
# ----> 3 x = uniform_sampling(parameters={'min': 10, 'max': 20}, method='mcs', n_samples=n)
#       4 y = uniform_sampling(parameters={'min': 10, 'max': 20}, method='lhs', n_samples=n)
#       6 # Criar subplots lado a lado
#
# NameError: name 'uniform_sampling' is not defined

# %%
n = 3
x0 = uniform_sampling(parameters={'min': 10, 'max': 20}, method='mcs', n_samples=n, seed=25)
x1 = uniform_sampling({'min': 10, 'max': 20}, 'mcs', n, 25)
x2 = uniform_sampling({'min': 10, 'max': 20}, 'mcs', n, 25)
print(x0, '\n', x1, '\n', x2)
# Out:
# [11.607212332320078, 10.003120351710036, 12.16598464462817]
#  [11.607212332320078, 10.003120351710036, 12.16598464462817]
#  [11.607212332320078, 10.003120351710036, 12.16598464462817]

# %%
n = 100
x1 = normal_sampling({'mean': 10, 'sigma': 2}, 'lhs', n, 24)
x2 = normal_sampling({'mean': 10, 'sigma': 2}, 'lhs', n)
print(x1, '\n', x2)
# Out:
# [7.865589902331452, 4.2851987851073075, 15.303809327551644, 14.794403574789893, 14.693455634731695, 5.222521702136648, 14.700059509212064, 11.229360388044721, 10.638756072622456, 5.72817077150256, 14.261862733376216, 10.424421416596719, 6.9024639102411935, 6.0326660730868875, 6.528080160846677, 8.972604054317367, 6.7762326540280124, 10.841992313186726, 13.612167025250885, 12.640245349954988, 11.793349090138907, 13.112149151798924, 12.702654202454982, 9.812634716687695, 7.649931847142971, 7.462364491307785, 10.967649698739978, 8.535948223296973, 13.043129560544315, 8.76745037607809, 9.699873895895479, 8.214326435488257, 7.010362903984867, 11.305829705816711, 8.028432756152174, 7.137447301389651, 7.372171858212435, 10.374223742551292, 8.9286636794742, 9.149833493834588, 7.604739207373374, 7.467653859632664, 8.353690553305269, 7.467556783559504, 8.884622652563667, 12.02811266574857, 10.052258451750369, 12.209975198393753, 12.357896922738679, 11.369163655887975, 8.440216487870162, 8.0542
# ...

# %%
# Sampling
n = 400
x = normal_sampling({'mean': 10, 'sigma': 2}, 'mcs', n)
y = normal_sampling({'mean': 10, 'sigma': 2}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Density')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Density')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 400
x = gumbel_max_sampling({'mean': 10, 'sigma': 2}, 'mcs', n)
y = gumbel_max_sampling({'mean': 10, 'sigma': 2}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Density')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Density')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Sampling
n = 400
x = gumbel_min_sampling({'mean': 10, 'sigma': 2}, 'mcs', n)
y = gumbel_min_sampling({'mean': 10, 'sigma': 2}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Density')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Density')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
x
# Out:
# [np.float64(9.514995383001851),
#  np.float64(11.307439988444997),
#  np.float64(10.829653565267881),
#  np.float64(5.64959463395906),
#  np.float64(11.00706771585563),
#  np.float64(8.569610467250326),
#  np.float64(6.522962808758382),
#  np.float64(9.173185757103331),
#  np.float64(10.656232106006112),
#  np.float64(11.170785405991763),
#  np.float64(7.558367100512703),
#  np.float64(10.08390925122066),
#  np.float64(12.760621758999982),
#  np.float64(9.157469368195594),
#  np.float64(10.614760246117397),
#  np.float64(11.019249386458023),
#  np.float64(11.324301016962028),
#  np.float64(11.500241002927417),
#  np.float64(12.655544214777692),
#  np.float64(11.055946306350743),
#  np.float64(11.986798913684513),
#  np.float64(10.537612360219164),
#  np.float64(11.821487132513072),
#  np.float64(10.584648859561709),
#  np.float64(9.923378863767981),
#  np.float64(10.84080446943668),
#  np.float64(11.032911080981219),
#  np.float64(11.50731401827477),
# ...

# %%
# Sampling
n = 400
x = triangular_sampling({'min': 2, 'mode': 6, 'max': 7}, 'mcs', n)
y = triangular_sampling({'min': 2, 'mode': 6, 'max': 7}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=30, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Densidade')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=30, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Valores')
axes[1].set_ylabel('Densidade')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
x
# Out:
# [np.float64(5.7134117053406035),
#  np.float64(5.0265806222726965),
#  np.float64(4.1130482253060805),
#  np.float64(5.374819468352753),
#  np.float64(5.021115523383466),
#  np.float64(6.006545178269637),
#  np.float64(5.513092054505339),
#  np.float64(3.731752977558688),
#  np.float64(4.606474869121085),
#  np.float64(3.4831058227871075),
#  np.float64(4.136618491006561),
#  np.float64(4.079741221930512),
#  np.float64(2.6870990108791775),
#  np.float64(6.327559785633333),
#  np.float64(4.422975060421482),
#  np.float64(5.68032543769762),
#  np.float64(4.946650930306552),
#  np.float64(6.047842100596311),
#  np.float64(6.153555227935112),
#  np.float64(6.12441269033247),
#  np.float64(4.815384534960072),
#  np.float64(6.376342333638164),
#  np.float64(5.463529771622804),
#  np.float64(3.9448542530135686),
#  np.float64(4.874425501516075),
#  np.float64(4.613345411743016),
#  np.float64(5.000970620580439),
#  np.float64(6.283937455188029),
#  np.float64(3.9384037369571754),
# ...

# %%
# Sampling

n = 10000
x = lognormal_sampling({'mean': 1, 'sigma': 0.4}, 'mcs', n)
y = lognormal_sampling({'mean': 1, 'sigma': 0.4}, 'lhs', n)

# Criar subplots lado a lado
fig, axes = plt.subplots(1, 2, figsize=(7, 3))

# Primeiro gráfico: Histograma e KDE para dados1
sns.histplot(x, kde=True, bins=20, color='blue', ax=axes[0], alpha=0.6, edgecolor='black')
axes[0].set_title('MCS Sampling')
axes[0].set_xlabel('Values')
axes[0].set_ylabel('Density')

# Segundo gráfico: Histograma e KDE para dados2
sns.histplot(y, kde=True, bins=20, color='green', ax=axes[1], alpha=0.6, edgecolor='black')
axes[1].set_title('LHS Sampling')
axes[1].set_xlabel('Values')
axes[1].set_ylabel('Density')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
f = {'type': 'normal', 'parameters': {'mean': 40.3, 'sigma': 4.64, 'corr': {'pho': -0.30, 'var': 1}}, 'stochastic variable': False}
p = {'type': 'normal', 'parameters': {'mean': 10.2, 'sigma': 1.12}, 'stochastic variable': False}
w = {'type': 'normal', 'parameters': {'mean': 0.25, 'sigma': 0.025}, 'stochastic variable': False}
j=[f, p, w]
for i in j:
    if 'seed' not in i:
        i['seed'] = None

# %%
x = sampling(n_samples=10, model={'model sampling': 'mcs'}, variables_setup=j)
x
# Out:
# normal corrrrrr 0 1
# parameters_g {'mean': 40.3, 'sigma': 4.64}
# parameters_b {'mean': 10.2, 'sigma': 1.12}
# normal 2
# array([[35.9553105 ,  9.74821215,  0.28576742],
#        [32.52972829,  8.72802469,  0.27828765],
#        [39.90328587,  9.61612335,  0.20881886],
#        [41.91319203,  9.08049587,  0.23139264],
#        [43.6812274 ,  9.10271984,  0.22869384],
#        [42.93425828,  9.85465696,  0.21939493],
#        [42.7340735 , 10.39164765,  0.25231468],
#        [36.74374858, 11.44255712,  0.2658654 ],
#        [31.54562602,  9.36392218,  0.21198047],
#        [49.18494105,  6.03631874,  0.26406261]])
