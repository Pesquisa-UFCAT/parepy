# %%
import os
import pandas as pd
import numpy as np
import pandas as pd
from typing import Callable, Optional
import sys
sys.path.append(r'C:\Users\rezio\OneDrive\Documentos\.git codes\parepy')

from parepy_toolbox import pare as parepy
from parepy_toolbox import common_library as parepyco

# %%
folder = "resultados_amostragem/"
df_all, pf_df, beta_df = parepy.reprocess_sampling_results(folder)
print("PF:", pf_df)
print("Beta:", beta_df)
df_all
# Out:
# 2 arquivos carregados. Total de amostras: 100000.
# Reavaliação concluída com sucesso.
# PF:       pf_G
# 0  0.24506
# Beta:      beta_G
# 0  0.690118
#             X_0        X_1        G_0  I_G_0
# 0      0.913547   9.192383   0.337818      0
# 1      1.111866   8.778022   8.403744      0
# 2      1.230379  11.283889  11.998435      0
# 3      1.026863  11.567146   1.967523      0
# 4      1.057423   8.727016   6.052378      0
# ...         ...        ...        ...    ...
# 99995  0.904666  10.102897  -0.847927      1
# 99996  1.073601  10.479175   4.988991      0
# 99997  1.149151   9.153290   9.815570      0
# 99998  0.983309  10.927411   0.957050      0
# 99999  0.860014  10.395627  -2.444545      1
#
# [100000 rows x 4 columns]
